# %%
import networkx as nx

# Create a weighted graph
G = nx.Graph()
G.add_weighted_edges_from([('A', 'B', 2), ('A', 'C', 3), ('B', 'D', 5), ('B', 'E', 5), ('C', 'F', 6),('D', 'E', 6)])

# Calculate node positions using spring layout
pos = nx.spring_layout(G)
print(pos)

# Draw the graph with edge labels
nx.draw(G, pos, with_labels=True)
edge_labels = nx.get_edge_attributes(G, 'weight')
nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
# Out:
# {'A': array([0.19049601, 0.14501645]), 'B': array([-0.41904184, -0.31897018]), 'C': array([0.68359776, 0.52036058]), 'D': array([-0.63519821, -0.6750843 ]), 'E': array([-0.81985372, -0.43253723]), 'F': array([1.        , 0.76121468])}
# {('A', 'B'): Text(-0.11427291218536999, -0.08697686590131118, '2'),
#  ('A', 'C'): Text(0.43704688618368276, 0.33268851141227246, '3'),
#  ('B', 'D'): Text(-0.5271200248011636, -0.4970272367742409, '5'),
#  ('B', 'E'): Text(-0.6194477800769237, -0.3757537053185015, '5'),
#  ('C', 'F'): Text(0.841798879674648, 0.6407876310518656, '6'),
#  ('D', 'E'): Text(-0.7275259674892778, -0.5538107651505544, '6')}
